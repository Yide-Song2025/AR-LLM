# %%
# import os
# from google.colab import drive
# drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Files/COMP545_PROJECT

# %%
import os
import json
import argparse
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from tqdm import tqdm

from utils.utils import load_jsonl, InferenceDataset
from utils.model import BERTBinaryClassifier, MultiClassClassifier

# %% [markdown]
# Load Model INFO

# %%
# 分别加载seen和unseen模型信息
seen_model_info_file_path = 'data/model_data/seen_models.json'
unseen_model_info_file_path = 'data/model_data/unseen_models.json'
seen_model_info = pd.read_json(seen_model_info_file_path).T
unseen_model_info = pd.read_json(unseen_model_info_file_path).T

seen_models = list(seen_model_info.index)
unseen_models = list(unseen_model_info.index)
print(f"Seen models ({len(seen_models)}): {seen_models}")
print(f"Unseen models ({len(unseen_models)}): {unseen_models}")
# Out:
# Seen models (7): ['Qwen/Qwen2.5-72B-Instruct', 'meta-llama/Llama-3.3-70B-Instruct', 'Qwen/Qwen2.5-32B-Instruct', 'deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', 'meta-llama/Llama-3.1-8B-Instruct', 'meta-llama/Llama-3.2-3B-Instruct', 'Qwen/Qwen2.5-0.5B-Instruct']
# Unseen models (7): ['Qwen/Qwen2.5-1.5B-Instruct', 'Qwen/Qwen2.5-3B-Instruct', 'Qwen/Qwen2.5-7B-Instruct', 'deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', 'meta-llama/Llama-3.2-1B-Instruct', 'meta-llama/Llama-3.1-70B-Instruct', 'Qwen/Qwen2.5-14B-Instruct']

# %%
# 分别构建seen和unseen模型的feature_cost
seen_model_info_feature_cost = seen_model_info[['feature_vector', 'co2_cost']].rename(
    columns={"feature_vector": "model_feature_vector", "co2_cost": "model_co2_cost"})
unseen_model_info_feature_cost = unseen_model_info[['feature_vector', 'co2_cost']].rename(
    columns={"feature_vector": "model_feature_vector", "co2_cost": "model_co2_cost"})

print("Seen model features:")
print(seen_model_info_feature_cost)
print("\nUnseen model features:")
print(unseen_model_info_feature_cost)
# Out:
# Seen model features:
#                                                                        model_feature_vector  \
# Qwen/Qwen2.5-72B-Instruct                      [0.7256, 0.5891000000000001, 0.5626, 0.5949]
# meta-llama/Llama-3.3-70B-Instruct                          [0.6915, 0.4554, 0.5332, 0.6615]
# Qwen/Qwen2.5-32B-Instruct                                  [0.6874, 0.6171, 0.5667, 0.5866]
# deepseek-ai/DeepSeek-R1-Distill-Qwen-14B       [0.5912000000000001, 0.5944, 0.4667, 0.6098]
# meta-llama/Llama-3.1-8B-Instruct              [0.5077, 0.15410000000000001, 0.3798, 0.3874]
# meta-llama/Llama-3.2-3B-Instruct                           [0.4586, 0.1631, 0.3195, 0.2659]
# Qwen/Qwen2.5-0.5B-Instruct                [0.3307, 0.08990000000000001, 0.17200000000000...
#
#                                          model_co2_cost
# Qwen/Qwen2.5-72B-Instruct                         47.65
# meta-llama/Llama-3.3-70B-Instruct                 76.56
# ...

# %%
result_df = pd.read_json('data/feature_vectors/OOD/extracted_dataset_samples_new_ood_features.jsonl', lines=True)
result_df
# Out:
# C:\Users\Scott\AppData\Local\Temp\ipykernel_30952\1280308737.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   result_df = pd.read_json('data/feature_vectors/OOD/extracted_dataset_samples_new_ood_features.jsonl', lines=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result_df = pd.read_json('data/feature_vectors/OOD/extracted_dataset_samples_new_ood_features.jsonl', lines=True)
#       2 result_df
#
# File e:\Application\anaconda3\envs\noesis\lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
# ...

# %%
ID_results_df = pd.read_json('data/feature_vectors/ID/extracted_dataset_samples_new_merged_features_test.jsonl', lines=True)
ID_results_df
# Out:
#             query_id   dataset  \
# 0         tele_10598  telequad
# 1          tele_6920   teleqna
# 2          tele_2767   teleqna
# 3     mmlu_pro_q1619  mmlu_pro
# 4     mmlu_pro_q8483  mmlu_pro
# ...              ...       ...
# 3192  mmlu_pro_q1931  mmlu_pro
# 3193       tele_5567   teleqna
# 3194        bbh_q819       bbh
# 3195       bbh_q3648       bbh
# 3196       tele_2239   teleqna
#
#                                                   query  \
# 0               When are there new charges to the user?
# 1     What is the horizontal separation recommended ...
# 2     What kind of applications require ultra-low de...
# 3     In chloroplasts, a certain protein is found in...
# 4     A 20% target contribution margin is set for Du...
# ...                                                 ...
# 3192  What mass of calcium bromide CaBr_2, is needed...
# 3193  What is the duration called that the UE waits ...
# 3194  In the following sentences, explain the antece...
# ...

# %% [markdown]
# Generate perdiction reuslt for all different alpha

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# %%
# Neural Collaborative Filtering (NeuMF) style Router
class RouterNN(nn.Module):
    def __init__(self, query_vector, model_vector, latent_dim_mf=32, latent_dim_mlp=32,
                 config_layers=(256, 128), dropout_rate=0.1, output_size=1):
        super(RouterNN, self).__init__()

        # MLP path projections
        self.q_proj_mlp = nn.Linear(query_vector, latent_dim_mlp)
        self.m_proj_mlp = nn.Linear(model_vector, latent_dim_mlp)

        # MF path projections
        self.q_proj_mf = nn.Linear(query_vector, latent_dim_mf)
        self.m_proj_mf = nn.Linear(model_vector, latent_dim_mf)

        # MLP layers
        self.fc_layers = nn.ModuleList()
        input_size = latent_dim_mlp * 2
        for hidden_size in config_layers:
            self.fc_layers.append(nn.Linear(input_size, hidden_size))
            input_size = hidden_size
        self.dropout = nn.Dropout(dropout_rate)

        # Output layer: MLP output + MF output
        self.output_layer = nn.Linear(config_layers[-1] + latent_dim_mf, output_size)

        self._init_weight_()

    def _init_weight_(self):
        nn.init.normal_(self.q_proj_mlp.weight, std=0.01)
        nn.init.normal_(self.m_proj_mlp.weight, std=0.01)
        nn.init.normal_(self.q_proj_mf.weight, std=0.01)
        nn.init.normal_(self.m_proj_mf.weight, std=0.01)

        for fc in self.fc_layers:
            nn.init.xavier_uniform_(fc.weight)
            nn.init.zeros_(fc.bias)

        nn.init.kaiming_uniform_(self.output_layer.weight, nonlinearity='sigmoid')
        nn.init.zeros_(self.output_layer.bias)

    def forward(self, query, model):
        # MLP path
        q_mlp = torch.relu(self.q_proj_mlp(query))
        m_mlp = torch.relu(self.m_proj_mlp(model))
        mlp_vector = torch.cat([q_mlp, m_mlp], dim=-1)

        for fc in self.fc_layers:
            mlp_vector = torch.relu(fc(mlp_vector))
            mlp_vector = self.dropout(mlp_vector)

        # MF path
        q_mf = self.q_proj_mf(query)
        m_mf = self.m_proj_mf(model)
        mf_vector = torch.mul(q_mf, m_mf)

        # Concat MLP + MF
        output_vector = torch.cat([mlp_vector, mf_vector], dim=-1)

        out = self.output_layer(output_vector)
        return out

# %%
def find_the_best_alpha(model_feature_and_cost_df, query_vector_df, accuracy_perdictor_model_pth, device):
  # model set up
  route_model = RouterNN(query_vector=5, model_vector=4, latent_dim_mf=32, latent_dim_mlp=32, dropout_rate=0.1, output_size=1)
  route_model.load_state_dict(torch.load(accuracy_perdictor_model_pth))
  route_model.to(device)
  route_model.eval()

  # query df setting
  query_id_and_vector = query_vector_df[['query_id','feature_vector']]

  # Normalize co2 cost
  cost_min = model_feature_and_cost_df['model_co2_cost'].min()
  cost_max = model_feature_and_cost_df['model_co2_cost'].max()

  # Step 1: Run inference ONCE for all (query, model) pairs
  print("Running inference for all (query, model) pairs...")
  inference_cache = {}  # (query_id, model_name) -> (prob_correct, co2_cost_norm)

  for query_id, input_query_vector in tqdm(query_id_and_vector.itertuples(index=False), desc="Inference", total=len(query_id_and_vector)):
    for model_name, model_vector, co2_cost in model_feature_and_cost_df.itertuples(index=True):
      input_query_tensor = torch.tensor(input_query_vector, dtype=torch.float32).unsqueeze(0).to(device)
      model_vector_tensor = torch.tensor(model_vector, dtype=torch.float32).unsqueeze(0).to(device)
      with torch.no_grad():
        logit = route_model(input_query_tensor, model_vector_tensor)
        prob_correct = torch.sigmoid(logit).item()
      co2_cost_norm = (co2_cost - cost_min) / (cost_max - cost_min)
      inference_cache[(query_id, model_name)] = (prob_correct, co2_cost_norm)

  # Step 2: Search alpha using cached results (no more inference)
  print("Searching best alpha...")
  query_ids = query_id_and_vector['query_id'].tolist()
  model_names = model_feature_and_cost_df.index.tolist()

  results = {}
  for alpha in tqdm(np.arange(0, 1, 0.01), desc="Alpha search"):
    query = []
    for query_id in query_ids:
      best_model_name = None
      best_score = -float('inf')
      for model_name in model_names:
        prob_correct, co2_cost_norm = inference_cache[(query_id, model_name)]
        score = (1 - alpha) * prob_correct - alpha * co2_cost_norm
        if score > best_score:
          best_score = score
          best_model_name = model_name
      query.append((query_id, best_model_name, best_score, alpha))
    results[alpha] = query
  return results

# %%
router_path = 'best_router_model.pth'
device='cuda' if torch.cuda.is_available() else 'cpu'

# %%
# ID数据评估
all_alpha_model_ID_seen = find_the_best_alpha(seen_model_info_feature_cost, ID_results_df, router_path, device)
all_alpha_model_ID_unseen = find_the_best_alpha(unseen_model_info_feature_cost, ID_results_df, router_path, device)
# Out:
# Running inference for all (query, model) pairs...
# Inference: 100%|██████████| 3197/3197 [00:06<00:00, 474.40it/s]
# Searching best alpha...
# Alpha search: 100%|██████████| 100/100 [00:00<00:00, 148.29it/s]
# Running inference for all (query, model) pairs...
# Inference: 100%|██████████| 3197/3197 [00:06<00:00, 479.73it/s]
# Searching best alpha...
# Alpha search: 100%|██████████| 100/100 [00:00<00:00, 142.39it/s]

# %%
# OOD数据评估
all_alpha_model_OOD_seen = find_the_best_alpha(seen_model_info_feature_cost, result_df, router_path, device)
all_alpha_model_OOD_unseen = find_the_best_alpha(unseen_model_info_feature_cost, result_df, router_path, device)
# Out:
# Running inference for all (query, model) pairs...
# Inference: 100%|██████████| 1301/1301 [00:02<00:00, 485.58it/s]
# Searching best alpha...
# Alpha search: 100%|██████████| 100/100 [00:00<00:00, 363.32it/s]
# Running inference for all (query, model) pairs...
# Inference: 100%|██████████| 1301/1301 [00:03<00:00, 399.61it/s]
# Searching best alpha...
# Alpha search: 100%|██████████| 100/100 [00:00<00:00, 356.95it/s]

# %%
# ID数据保存
all_data_ID_seen = [row for rows in all_alpha_model_ID_seen.values() for row in rows]
pd.DataFrame(all_data_ID_seen, columns=['query_id', 'best_model', 'score', 'alpha']).to_csv("./results/all_alpha_model_ID_seen.csv", index=False)

all_data_ID_unseen = [row for rows in all_alpha_model_ID_unseen.values() for row in rows]
pd.DataFrame(all_data_ID_unseen, columns=['query_id', 'best_model', 'score', 'alpha']).to_csv("./results/all_alpha_model_ID_unseen.csv", index=False)

print("Saved ID results.")
# Out:
# Saved ID results.

# %%
# OOD数据保存
all_data_OOD_seen = [row for rows in all_alpha_model_OOD_seen.values() for row in rows]
pd.DataFrame(all_data_OOD_seen, columns=['query_id', 'best_model', 'score', 'alpha']).to_csv("./results/all_alpha_model_OOD_seen.csv", index=False)

all_data_OOD_unseen = [row for rows in all_alpha_model_OOD_unseen.values() for row in rows]
pd.DataFrame(all_data_OOD_unseen, columns=['query_id', 'best_model', 'score', 'alpha']).to_csv("./results/all_alpha_model_OOD_unseen.csv", index=False)

print("Saved OOD results.")
# Out:
# Saved OOD results.

# %% [markdown]
# Oracle Baseline: Route each query to the cheapest model that answers correctly

# %%
# 加载地面真值数据
extracted_data_ID = pd.read_json('data/model_data/extracted_dataset_samples_new_merged.jsonl', lines=True)
extracted_data_OOD = pd.read_json('data/model_data/extracted_dataset_samples_ood.jsonl', lines=True)

# 去重：同一(query_id, model)可能出现多次，取平均correct
unique_extracted_ID = extracted_data_ID.groupby(['query_id', 'model'])['correct'].mean().reset_index()
unique_extracted_OOD = extracted_data_OOD.groupby(['query_id', 'model'])['correct'].mean().reset_index()

print(f"ID ground truth: {len(unique_extracted_ID)} (query, model) pairs")
print(f"OOD ground truth: {len(unique_extracted_OOD)} (query, model) pairs")
# Out:
# ID ground truth: 445684 (query, model) pairs
# OOD ground truth: 20816 (query, model) pairs

# %%
def compute_oracle_baseline(extracted_data, model_list, cost_map):
    """
    Oracle基准：对每个查询，选择能正确回答且成本最低的模型。
    若无模型正确回答，选最便宜的模型（accuracy=0）。

    Args:
        extracted_data: DataFrame with columns [query_id, model, correct]
        model_list: list of candidate model names
        cost_map: dict/Series mapping model name -> co2_cost

    Returns:
        oracle_accuracy, oracle_mean_cost, oracle_df
    """
    # 仅保留候选模型
    df = extracted_data[extracted_data['model'].isin(model_list)].copy()
    df['co2_cost'] = df['model'].map(cost_map)

    # 找每个query的最便宜模型（fallback用）
    cheapest_model = min(model_list, key=lambda m: cost_map[m])

    oracle_rows = []
    for query_id, group in df.groupby('query_id'):
        correct_models = group[group['correct'] >= 0.5]  # correct >= 0.5 视为正确（处理平均值情况）
        if len(correct_models) > 0:
            # 选正确模型中成本最低的
            best = correct_models.loc[correct_models['co2_cost'].idxmin()]
            oracle_rows.append({
                'query_id': query_id,
                'oracle_model': best['model'],
                'correct': 1,
                'cost': best['co2_cost']
            })
        else:
            # 无模型正确回答，选最便宜的
            oracle_rows.append({
                'query_id': query_id,
                'oracle_model': cheapest_model,
                'correct': 0,
                'cost': cost_map[cheapest_model]
            })

    oracle_df = pd.DataFrame(oracle_rows)
    oracle_accuracy = oracle_df['correct'].mean()
    oracle_mean_cost = oracle_df['cost'].mean()
    return oracle_accuracy, oracle_mean_cost, oracle_df

# %%
# 构建成本映射
all_model_info = pd.read_json('data/model_data/models_info.json').T
cost_map = all_model_info['co2_cost']

# 计算4种场景的Oracle基准
# ID + Seen
oracle_acc_ID_seen, oracle_cost_ID_seen, oracle_df_ID_seen = compute_oracle_baseline(
    unique_extracted_ID, seen_models, cost_map)
# ID + Unseen
oracle_acc_ID_unseen, oracle_cost_ID_unseen, oracle_df_ID_unseen = compute_oracle_baseline(
    unique_extracted_ID, unseen_models, cost_map)
# OOD + Seen
oracle_acc_OOD_seen, oracle_cost_OOD_seen, oracle_df_OOD_seen = compute_oracle_baseline(
    unique_extracted_OOD, seen_models, cost_map)
# OOD + Unseen
oracle_acc_OOD_unseen, oracle_cost_OOD_unseen, oracle_df_OOD_unseen = compute_oracle_baseline(
    unique_extracted_OOD, unseen_models, cost_map)

print("=== Oracle Baseline Results ===")
print(f"ID  + Seen:   accuracy={oracle_acc_ID_seen:.4f}, mean_cost={oracle_cost_ID_seen:.4f}")
print(f"ID  + Unseen: accuracy={oracle_acc_ID_unseen:.4f}, mean_cost={oracle_cost_ID_unseen:.4f}")
print(f"OOD + Seen:   accuracy={oracle_acc_OOD_seen:.4f}, mean_cost={oracle_cost_OOD_seen:.4f}")
print(f"OOD + Unseen: accuracy={oracle_acc_OOD_unseen:.4f}, mean_cost={oracle_cost_OOD_unseen:.4f}")
# Out:
# === Oracle Baseline Results ===
# ID  + Seen:   accuracy=0.8595, mean_cost=6.8661
# ID  + Unseen: accuracy=0.8526, mean_cost=3.1329
# OOD + Seen:   accuracy=0.8163, mean_cost=4.7303
# OOD + Unseen: accuracy=0.7394, mean_cost=2.0076

# %%
# 保存Oracle结果
oracle_df_ID_seen.to_csv("./results/oracle_baseline_ID_seen.csv", index=False)
oracle_df_ID_unseen.to_csv("./results/oracle_baseline_ID_unseen.csv", index=False)
oracle_df_OOD_seen.to_csv("./results/oracle_baseline_OOD_seen.csv", index=False)
oracle_df_OOD_unseen.to_csv("./results/oracle_baseline_OOD_unseen.csv", index=False)
print("Saved Oracle baseline results.")
# Out:
# Saved Oracle baseline results.
